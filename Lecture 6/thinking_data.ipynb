# %%
import json

# %%
# Load the data
def load_data(filename):
    with open(filename, "r") as f:
        data = json.load(f)
        
    return data

# %%
data = load_data("store_data.json")
print(data)
print(type(data))
# Out:
# [{'name': 'Alice', 'rating': '5', 'feedback': 'Great product!', 'age': '25'}, {'name': 'Bob', 'rating': 'four', 'feedback': 'Average', 'age': '30'}, {'name': 'CharLie', 'rating': ' two ', 'feedback': 'BAD EXPERIENCE'}, {'name': 'Diana', 'rating': ' 5', 'feedback': 'Loved it! Even could be better', 'age': '28'}, {'name': 'Eve', 'rating': ' 3.5', 'feedback': 'Average - Could be better. ', 'age': '20'}, {'name': 'Alice', 'rating': ' 5', 'feedback': 'Great product again!', 'age': '25'}]
# <class 'list'>

# %%
# clean & structure the data 

def clean_data(data):
    for user in data:
        print(user)

# %%
clean_data(data)
# Out:
# {'name': 'Alice', 'rating': '5', 'feedback': 'Great product!', 'age': '25'}
# {'name': 'Bob', 'rating': 'four', 'feedback': 'Average', 'age': '30'}
# {'name': 'CharLie', 'rating': ' two ', 'feedback': 'BAD EXPERIENCE'}
# {'name': 'Diana', 'rating': ' 5', 'feedback': 'Loved it! Even could be better', 'age': '28'}
# {'name': 'Eve', 'rating': ' 3.5', 'feedback': 'Average - Could be better. ', 'age': '20'}
# {'name': 'Alice', 'rating': ' 5', 'feedback': 'Great product again!', 'age': '25'}

# %% [markdown]
# # Filter the rating column

# %%
# Clean & Structure the data. 
def clean_data(data):
    for user in data:
        # acces raw_rating into the json 
        raw_rating = user["rating"].strip().lower()
        
        print(raw_rating)

# %%
clean_data(data)
# Out:
# 5
# four
# two
# 5
# 3.5
# 5

# %% [markdown]
# # convert these values into numbers

# %%
# Clean & Structure the data. 
def clean_data(data):
    text_to_num = {"one":1, "two": 2,"three": 3, "four": 4, "five": 5}
    cleaned_data = [] 
    unique_users = set() 
    
    for user in data:

        #clean rating 
        raw_rating = str(user["rating"]).strip().lower()
        if(raw_rating in text_to_num):
            raw_rating = text_to_num[raw_rating]
            
        # print(raw_rating)  
        user["rating"] = raw_rating # update the rating value


        # Handle missing values. 
        raw_age = user.get("age")
        if(raw_age == None):
            user["age"] = None


        # Deduplication     
        if(user["name"].strip() in unique_users):
            continue    
        unique_users.add(user["name"])
        cleaned_data.append(user)     
            
    return cleaned_data

# %%
data = clean_data(data)
print(data)
# Out:
# [{'name': 'Alice', 'rating': '5', 'feedback': 'Great product!', 'age': '25'}, {'name': 'Bob', 'rating': '4', 'feedback': 'Average', 'age': '30'}, {'name': 'CharLie', 'rating': '2', 'feedback': 'BAD EXPERIENCE', 'age': None}, {'name': 'Diana', 'rating': '5', 'feedback': 'Loved it! Even could be better', 'age': '28'}, {'name': 'Eve', 'rating': '3.5', 'feedback': 'Average - Could be better. ', 'age': '20'}]

# %%
# Get meaningful insights from data 

def get_insights(data):
    
     #average rating 
    tot_rating = 0
    for user in data:
        tot_rating += float(user["rating"])

    print(f"avg rating = {tot_rating/len(data)}")

    # percentage of users with poor rating. 
    poor_ratings= 0 
    for user in data:
        if(float(user["rating"]) < 3):
            poor_ratings += 1

    print(f"% of user with poor rating = {poor_ratings/len(data) * 100}%")

# %%
get_insights(data)
# Out:
# avg rating = 3.9
# % of user with poor rating = 20.0%

# %%
def get_recommendations(data):
    recommendations = []

    for user in data:
        curr_recomm = {}
        curr_recomm["name"] = user["name"]

        if float(user["rating"]) >= 4:
            curr_recomm["brand"] = "Apple"
        else:
            curr_recomm["brand"] = "Samsung"

        recommendations.append(curr_recomm)

    return recommendations

# %%
get_recommendations(data)
# Out:
# [{'name': 'Alice', 'brand': 'Apple'},
#  {'name': 'Bob', 'brand': 'Apple'},
#  {'name': 'CharLie', 'brand': 'Samsung'},
#  {'name': 'Diana', 'brand': 'Apple'},
#  {'name': 'Eve', 'brand': 'Samsung'}]
